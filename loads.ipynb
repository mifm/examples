# %% [markdown]
# <a href="https://colab.research.google.com/github/mifm/examples/blob/master/loads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loads
# Topfarm supports load constraints by evaluating a trained surrogate model at each iteration. There are currently two different high-level load workflows implemented, namely the Dynamic Wake Meandering (DWM) and the Frandsen approach.
# ### DWM
# In DWM the loads are calculated for all turbines for all flowcases and for all turbine interactions. This means that for each turbine it will look at the wakes coming from all other turbines (individually). The results are subsequently reduced to only one load per turbine by applying a soft max. This is done to create a differentiable expression for the max load instead of just taking the max load, which would not work well in a gradient-based optimization.
# ### Frandsen
# In the Frandsen implementation, the turbulence is aggregated from different sectors with the W̦hler exponent as described in the IEC. Loads are then calculated based on the effective turbulence. Alternatively, if one would like to improve the fidelity by trading off some memory consumption the loads could be calculated based on the all wind direction sectors and subsequently aggregated with the W̦hler exponent.
#
# ## Load Surrogates
# Topfarm can utilize surrogates trained with a range of different algorithms and softwares, namely scikit-learn, OpenTURNS, TensorFlow and the artificial neural networks code (wind2loads ANN) developed at DTU.

# %% [markdown]
# [Try this yourself](https://colab.research.google.com/github/DTUWindEnergy/TopFarm2/blob/master/docs/notebooks/loads.ipynb) (requires google account)

# %% [markdown]
# ## Install wind2loads
# In this exercisw we will use the wind2loads artificial neural networks code to predict the turbine loads of the DTU 10MW reference turbine.

# %%
# %%capture
# !pip install git+https://gitlab.windenergy.dtu.dk/TOPFARM/wind2loads.git
import wind2loads
import w2l
# !pip install git+https://gitlab.windenergy.dtu.dk/TOPFARM/workshop-december-2019.git
import numpy as np
import topfarm
from topfarm import TopFarmProblem
from topfarm.easy_drivers import EasyScipyOptimizeDriver
from topfarm.constraint_components.spacing import SpacingConstraint
from topfarm.constraint_components.boundary import XYBoundaryConstraint
from topfarm.plotting import XYPlotComp
import workshop
# !git clone https://gitlab.windenergy.dtu.dk/TOPFARM/workshop-december-2019.git
workshop.w2l_path = 'workshop-december-2019/workshop/wind2loads_ann'
import workshop.workflow as wf
# Out:
# Collecting git+https://gitlab.windenergy.dtu.dk/TOPFARM/wind2loads.git
#   Cloning https://gitlab.windenergy.dtu.dk/TOPFARM/wind2loads.git to /tmp/pip-req-build-dmy364hs
#   Running command git clone -q https://gitlab.windenergy.dtu.dk/TOPFARM/wind2loads.git /tmp/pip-req-build-dmy364hs
# Requirement already satisfied (use --upgrade to upgrade): Wind2Loads==0.0.1 from git+https://gitlab.windenergy.dtu.dk/TOPFARM/wind2loads.git in ./workshop-december-2019/wind2loads
# Requirement already satisfied: topfarm in /usr/local/lib/python3.6/dist-packages (from Wind2Loads==0.0.1) (2.2.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from topfarm->Wind2Loads==0.0.1) (0.22.2.post1)
# Requirement already satisfied: openmdao==2.6 in /usr/local/lib/python3.6/dist-packages (from topfarm->Wind2Loads==0.0.1) (2.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from topfarm->Wind2Loads==0.0.1) (1.18.2)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from topfarm->Wind2Loads==0.0.1) (3.6.4)
# Requirement already satisfied: py-wake>=1.0.11 in /usr/local/lib/python3.6/dist-packages (from topfarm->Wind2Loads==0.0.1) (1.0.11)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.6/dist-packages (from topfarm->Wind2Loads==0.0.1) (0.4.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from topfarm->Wind2Loads==0.0.1) (3.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from topfarm->Wind2Loads==0.0.1) (1.4.1)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.6/dist-packages (from topfarm->Wind2Loads==0.0.1) (1.8.5)
# Requirement already satisfied: pytest-cov in /usr/local/lib/python3.6/dist-packages (from topfarm->Wind2Loads==0.0.1) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->topfarm->Wind2Loads==0.0.1) (0.14.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from openmdao==2.6->topfarm->Wind2Loads==0.0.1) (1.12.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from openmdao==2.6->topfarm->Wind2Loads==0.0.1) (2.4.6)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from openmdao==2.6->topfarm->Wind2Loads==0.0.1) (2.4)
# Requirement already satisfied: pyDOE2 in /usr/local/lib/python3.6/dist-packages (from openmdao==2.6->topfarm->Wind2Loads==0.0.1) (1.3.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->topfarm->Wind2Loads==0.0.1) (0.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->topfarm->Wind2Loads==0.0.1) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->topfarm->Wind2Loads==0.0.1) (8.2.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->topfarm->Wind2Loads==0.0.1) (1.8.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->topfarm->Wind2Loads==0.0.1) (1.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest->topfarm->Wind2Loads==0.0.1) (46.0.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.6/dist-packages (from py-wake>=1.0.11->topfarm->Wind2Loads==0.0.1) (0.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from py-wake>=1.0.11->topfarm->Wind2Loads==0.0.1) (3.13)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->topfarm->Wind2Loads==0.0.1) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->topfarm->Wind2Loads==0.0.1) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->topfarm->Wind2Loads==0.0.1) (2.8.1)
# Requirement already satisfied: docutils>=0.11 in /usr/local/lib/python3.6/dist-packages (from sphinx->topfarm->Wind2Loads==0.0.1) (0.15.2)
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.6/dist-packages (from sphinx->topfarm->Wind2Loads==0.0.1) (2.8.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from sphinx->topfarm->Wind2Loads==0.0.1) (2.21.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from sphinx->topfarm->Wind2Loads==0.0.1) (20.3)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.6/dist-packages (from sphinx->topfarm->Wind2Loads==0.0.1) (1.2.0)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.6/dist-packages (from sphinx->topfarm->Wind2Loads==0.0.1) (2.0.0)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.6/dist-packages (from sphinx->topfarm->Wind2Loads==0.0.1) (2.11.1)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.6/dist-packages (from sphinx->topfarm->Wind2Loads==0.0.1) (2.1.3)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.6/dist-packages (from sphinx->topfarm->Wind2Loads==0.0.1) (0.7.12)
# Requirement already satisfied: sphinxcontrib-websupport in /usr/local/lib/python3.6/dist-packages (from sphinx->topfarm->Wind2Loads==0.0.1) (1.2.1)
# Requirement already satisfied: coverage>=4.4 in /usr/local/lib/python3.6/dist-packages (from pytest-cov->topfarm->Wind2Loads==0.0.1) (5.0.4)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->openmdao==2.6->topfarm->Wind2Loads==0.0.1) (4.4.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.6/dist-packages (from xarray->py-wake>=1.0.11->topfarm->Wind2Loads==0.0.1) (0.25.3)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.6/dist-packages (from babel!=2.0,>=1.3->sphinx->topfarm->Wind2Loads==0.0.1) (2018.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->sphinx->topfarm->Wind2Loads==0.0.1) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->sphinx->topfarm->Wind2Loads==0.0.1) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->sphinx->topfarm->Wind2Loads==0.0.1) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->sphinx->topfarm->Wind2Loads==0.0.1) (1.24.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.3->sphinx->topfarm->Wind2Loads==0.0.1) (1.1.1)
# Building wheels for collected packages: Wind2Loads
#   Building wheel for Wind2Loads (setup.py) ... done
#   Created wheel for Wind2Loads: filename=Wind2Loads-0.0.1-cp36-none-any.whl size=7693 sha256=d1fdd7eac65459a6008f9effa0f60e23e7ef9870b5d5f94dae9cbd27318cc308
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0wk2y0n5/wheels/f7/0a/79/6ea6bfdabcf701663fb668cb3b4e7ea612a51546aaeb11d5eb
# Successfully built Wind2Loads
# Collecting git+https://gitlab.windenergy.dtu.dk/TOPFARM/workshop-december-2019.git
#   Cloning https://gitlab.windenergy.dtu.dk/TOPFARM/workshop-december-2019.git to /tmp/pip-req-build-tie0_qo3
#   Running command git clone -q https://gitlab.windenergy.dtu.dk/TOPFARM/workshop-december-2019.git /tmp/pip-req-build-tie0_qo3
# Requirement already satisfied (use --upgrade to upgrade): workshop==0.0.0 from git+https://gitlab.windenergy.dtu.dk/TOPFARM/workshop-december-2019.git in ./workshop-december-2019
# Building wheels for collected packages: workshop
#   Building wheel for workshop (setup.py) ... done
#   Created wheel for workshop: filename=workshop-0.0.0-cp36-none-any.whl size=15439 sha256=10fc8d1c7e1c46b703d9f908601b5554a1dc8bb96163269141e2fd1f42aae70c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5vypz9rj/wheels/d0/22/67/401502bc288128f6355f24f9c9c9acb1905eadf464028a51e4
# Successfully built workshop
# fatal: destination path 'workshop-december-2019' already exists and is not an empty directory.
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.preprocessing.data module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.preprocessing. Anything that cannot be imported from sklearn.preprocessing is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator MinMaxScaler from version 0.21.3 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %% [markdown]
# ## Set up the problem
# In this example we will import most of the code for setting up the workflow.

# %%
def get_problem(maxiter=10, allowable_load=1.0, tol=1e-2):
    problem = TopFarmProblem(
            design_vars={topfarm.x_key: wf.site.initial_position[:, 0],
                         topfarm.y_key: wf.site.initial_position[:, 1]},
            cost_comp=wf.get_load_cost_comp(),
            driver=EasyScipyOptimizeDriver(maxiter=maxiter, tol=tol),
            constraints=[SpacingConstraint(wf.min_spacing),
                         XYBoundaryConstraint(wf.boundary),],
                post_constraints=[(ls, allowable_load) for ls in wf.load_signals],
            plot_comp=XYPlotComp(),
            approx_totals={'step':10},
            expected_cost=1e-6,)
    cost, state = problem.evaluate()
    max_load = {ls: np.array([problem[ls+'_abs'].max()]) for ls in wf.load_signals}
    problem.cost_comp.analytical_group.lifetime_comp.options['max_load'] = max_load
    return problem

# %% [markdown]
# ## Run the optimization
# In this example there is the option to change the maximum number of iterations, the tolerance of the optimization as well as the maximum allowable load. The maximum allowable load is set as a percentage of the loads calculated for the initial layout, meaning e.g. that allowable_load=1.0 is 100% of the initial loads. We will optimize on AEP of the wind farm.

# %%
problem = get_problem(5, 1.0)
cost, state, recorder = problem.optimize(disp=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d3c2d6935637> in <module>()
#       1 problem = get_problem(5, 1.0)
# ----> 2 cost, state, recorder = problem.optimize(disp=True)
#
# /usr/local/lib/python3.6/dist-packages/topfarm/_topfarm.py in optimize(self, state, disp)
#     420         self.setup()
#     421         t = time.time()
# --> 422         self.run_driver()
#     423         self.cleanup()
#     424         if disp:
#
# /usr/local/lib/python3.6/dist-packages/openmdao/core/problem.py in run_driver(self, case_prefix, reset_iter_counts)
#     564         self.model._clear_iprint()
#     565         with self.model._scaled_context_all():
# --> 566             return self.driver.run()
#     567
#     568     def run_once(self):
#
# /usr/local/lib/python3.6/dist-packages/openmdao/drivers/scipy_optimizer.py in run(self)
#     429                                   tol=self.options['tol'],
#     430                                   # callback=None,
# --> 431                                   options=self.opt_settings)
#     432             elif opt == 'basinhopping':
#     433                 from scipy.optimize import basinhopping
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     616     elif meth == 'slsqp':
#     617         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 618                                constraints, callback=callback, **options)
#     619     elif meth == 'trust-constr':
#     620         return _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     421             # Compute the derivatives of the objective function
#     422             # For some reason SLSQP wants g dimensioned to n+1
# --> 423             g = append(fprime(x), 0.0)
#     424
#     425             # Compute the normals of the constraints
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# /usr/local/lib/python3.6/dist-packages/openmdao/drivers/scipy_optimizer.py in _gradfunc(self, x_new)
#     671         try:
#     672             grad = self._compute_totals(of=self._obj_and_nlcons, wrt=self._dvlist,
# --> 673                                         return_format='array')
#     674             self._grad_cache = grad
#     675
#
# /usr/local/lib/python3.6/dist-packages/openmdao/core/driver.py in _compute_totals(self, of, wrt, return_format, global_names)
#     772
#     773             try:
# --> 774                 totals = total_jac.compute_totals()
#     775             finally:
#     776                 self._recording_iter.stack.pop()
#
# /usr/local/lib/python3.6/dist-packages/openmdao/core/total_jac.py in compute_totals(self)
#    1253
#    1254         # Linearize Model
# -> 1255         model._linearize(model._assembled_jac, sub_do_ln=model._linear_solver._linearize_children())
#    1256         model._linear_solver._linearize()
#    1257
#
# /usr/local/lib/python3.6/dist-packages/openmdao/core/group.py in _linearize(self, jac, sub_do_ln)
#    1673                 do_ln = sub_do_ln and (subsys._linear_solver is not None and
#    1674                                        subsys._linear_solver._linearize_children())
# -> 1675                 subsys._linearize(jac, sub_do_ln=do_ln)
#    1676
#    1677             # Update jacobian
#
# /usr/local/lib/python3.6/dist-packages/openmdao/core/group.py in _linearize(self, jac, sub_do_ln)
#    1664             with self._unscaled_context(outputs=[self._outputs]):
#    1665                 for approximation in itervalues(self._approx_schemes):
# -> 1666                     approximation.compute_approximations(self, jac=jac, total=True)
#    1667         else:
#    1668             if self._assembled_jac is not None:
#
# /usr/local/lib/python3.6/dist-packages/openmdao/approximation_schemes/finite_difference.py in compute_approximations(self, system, jac, total)
#     281                     for delta, coeff in zip(deltas, coeffs):
#     282                         self._run_point(system, wrt, idx, delta, out_tmp, in_tmp, result_array,
# --> 283                                         total)
#     284                         result_array *= coeff
#     285                         result._data += result_array
#
# /usr/local/lib/python3.6/dist-packages/openmdao/approximation_schemes/finite_difference.py in _run_point(self, system, in_name, idxs, delta, out_tmp, in_tmp, result_array, total)
#     359             pass
#     360
# --> 361         run_model()
#     362
#     363         result_array[:] = results_vec._data
#
# /usr/local/lib/python3.6/dist-packages/openmdao/core/system.py in run_solve_nonlinear(self)
#    2633         """
#    2634         with self._scaled_context_all():
# -> 2635             self._solve_nonlinear()
#    2636
#    2637     def run_apply_linear(self, vec_names, mode, scope_out=None, scope_in=None):
#
# /usr/local/lib/python3.6/dist-packages/openmdao/core/group.py in _solve_nonlinear(self)
#    1560
#    1561         with Recording(name + '._solve_nonlinear', self.iter_count, self):
# -> 1562             self._nonlinear_solver.solve()
#    1563
#    1564     def _guess_nonlinear(self):
#
# /usr/local/lib/python3.6/dist-packages/openmdao/solvers/nonlinear/nonlinear_runonce.py in solve(self)
#      38             # If this is not a parallel group, transfer for each subsystem just prior to running it.
#      39             else:
# ---> 40                 self._gs_iter()
#      41
#      42             rec.abs = 0.0
#
# /usr/local/lib/python3.6/dist-packages/openmdao/solvers/solver.py in _gs_iter(self)
#     648
#     649             if subsys.name in loc:
# --> 650                 subsys._solve_nonlinear()
#     651
#     652             system._check_reconf_update(subsys)
#
# /usr/local/lib/python3.6/dist-packages/openmdao/core/group.py in _solve_nonlinear(self)
#    1560
#    1561         with Recording(name + '._solve_nonlinear', self.iter_count, self):
# -> 1562             self._nonlinear_solver.solve()
#    1563
#    1564     def _guess_nonlinear(self):
#
# /usr/local/lib/python3.6/dist-packages/openmdao/solvers/nonlinear/nonlinear_runonce.py in solve(self)
#      38             # If this is not a parallel group, transfer for each subsystem just prior to running it.
#      39             else:
# ---> 40                 self._gs_iter()
#      41
#      42             rec.abs = 0.0
#
# /usr/local/lib/python3.6/dist-packages/openmdao/solvers/solver.py in _gs_iter(self)
#     648
#     649             if subsys.name in loc:
# --> 650                 subsys._solve_nonlinear()
#     651
#     652             system._check_reconf_update(subsys)
#
# /usr/local/lib/python3.6/dist-packages/openmdao/core/explicitcomponent.py in _solve_nonlinear(self)
#     218                                      self._discrete_outputs)
#     219                     else:
# --> 220                         self.compute(self._inputs, self._outputs)
#     221                 finally:
#     222                     self._inputs.read_only = False
#
# /content/workshop-december-2019/workshop/load_constraint_classes.py in compute(self, inputs, outputs)
#     118         types = np.round(np.asarray(_as_input_or_option(inputs, self.options, topfarm.type_key))).astype(np.int)
#     119         aep_calculator = self.options['aep_calculator']
# --> 120         AEP_GWh_ilk = aep_calculator.calculate_AEP(x_i=x, y_i=y, type_i=types)
#     121         dw_iil, hcw_iil, _, _ = aep_calculator.site.wt2wt_distances(
#     122                 x_i=x, y_i=y, h_i=aep_calculator.windTurbines.hub_height(types),
#
# /usr/local/lib/python3.6/dist-packages/py_wake/aep_calculator.py in calculate_AEP(self, x_i, y_i, h_i, type_i, wd, ws)
#      59             AEP in GWh
#      60         """
# ---> 61         self._run_wake_model(x_i=x_i, y_i=y_i, h_i=h_i, type_i=type_i, wd=wd, ws=ws)
#      62         AEP_GWh_ilk = self.power_ilk * self.P_ilk * 24 * 365 * 1e-9
#      63         return AEP_GWh_ilk
#
# /usr/local/lib/python3.6/dist-packages/py_wake/aep_calculator.py in _run_wake_model(self, x_i, y_i, h_i, type_i, wd, ws)
#      27
#      28         self.WS_eff_ilk, self.TI_eff_ilk, self.power_ilk, self.ct_ilk, self.WD_ilk, self.WS_ilk, self.TI_ilk, self.P_ilk =\
# ---> 29             self.wake_model.calc_wake(x_i, y_i, h_i, type_i, wd, ws)
#      30
#      31     def calculate_AEP(self, x_i, y_i, h_i=None, type_i=None, wd=None, ws=None):
#
# /usr/local/lib/python3.6/dist-packages/py_wake/wake_model.py in calc_wake(self, x_i, y_i, h_i, type_i, wd, ws)
#     174
#     175             # generate indexes of up wind(n_uw) and down wind(n_dw) turbines
# --> 176             n_uw = np.array([indices[uwi, i, l] for uwi, i, l in zip(dw_order_indices_dl[:, :j], i_wt_l, i_wd_l)]).T
#     177             n_dw = np.array([indices[i, dwi, l] for dwi, i, l in zip(dw_order_indices_dl[:, j + 1:], i_wt_l, i_wd_l)]).T
#     178
#
# KeyboardInterrupt:

# %% [markdown]
# ## Post Process
# During the optimization all variable are recorded. After it is finished one can see all the recorded variables by typing `recorder.keys()` and plot them by writing `plt.plot([your variable],'.')`. We can use this procedure to examine how the load constraint has developed during the optimization:

# %% [markdown]
# First we show the relative loads meaning the ratio between the load at each iteration and the initial loads:

# %%
import matplotlib.pyplot as plt
plt.figure()
for ls in wf.load_signals:
    plt.plot(np.max(recorder[ls], axis=1),'.',label=ls)
plt.grid()
plt.title('Load constraints')
plt.legend()
plt.ylabel('Load / Initial Load')
plt.xlabel('iteration')
plt.show()

# %% [markdown]
# Secondly we can also plot the absolute magnitude of the loads as a function of the iterations:

# %%
plt.figure()
for ls in wf.load_signals:
    ls += '_abs'
    plt.plot(np.max(recorder[ls], axis=1),'.',label=ls)
plt.grid()
plt.title('Load constraints')
plt.legend()
plt.ylabel('Load [kNm]')
plt.xlabel('iteration')
plt.show()
