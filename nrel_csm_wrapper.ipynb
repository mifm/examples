# %% [markdown]
# <a href="https://colab.research.google.com/github/mifm/examples/blob/master/nrel_csm_wrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/WISDEM/WISDEM.git --no-deps
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/WISDEM/WISDEM.git
#   Cloning https://github.com/WISDEM/WISDEM.git to /tmp/pip-req-build-85yn0fu3
#   Running command git clone --filter=blob:none --quiet https://github.com/WISDEM/WISDEM.git /tmp/pip-req-build-85yn0fu3
#   Resolved https://github.com/WISDEM/WISDEM.git to commit fb7cddf67d21a12f1a8e04e98833f49a447af7bf
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: WISDEM
#   Building wheel for WISDEM (pyproject.toml) ... done
#   Created wheel for WISDEM: filename=WISDEM-3.8-py3-none-any.whl size=4581333 sha256=1cfd4cd9df2e424b6233f1d0ffc7ab5ac1828cc77e82558ab845ca79b2386cd6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1ghzodfb/wheels/52/18/6c/8683bc75ae1ca6876395fa1d46d5de2eb35310bd132f8928f3
# Successfully built WISDEM
# Installing collected packages: WISDEM
# Successfully installed WISDEM-3.8

# %%
# !pip install openmdao
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openmdao
#   Downloading openmdao-3.23.0.tar.gz (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from openmdao) (3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from openmdao) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from openmdao) (1.7.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from openmdao) (2.25.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from openmdao) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->openmdao) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->openmdao) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->openmdao) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->openmdao) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->openmdao) (2.10)
# Building wheels for collected packages: openmdao
#   Building wheel for openmdao (setup.py) ... done
#   Created wheel for openmdao: filename=openmdao-3.23.0-py3-none-any.whl size=5806407 sha256=53646e0360ad29be50fdbe31013da6088dfbaebb3ff60deb4cbefa86e7e70015
#   Stored in directory: /root/.cache/pip/wheels/35/7d/84/03d1663a4f2694741021ba0a18aee54e254bbc89cf35df0ebd
# Successfully built openmdao
# Installing collected packages: openmdao
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wisdem 3.8 requires dearpygui, which is not installed.
# wisdem 3.8 requires marmot-agents>=0.2.5, which is not installed.
# wisdem 3.8 requires nlopt, which is not installed.
# wisdem 3.8 requires pydoe2, which is not installed.
# wisdem 3.8 requires python-benedict, which is not installed.
# wisdem 3.8 requires ruamel.yaml, which is not installed.
# wisdem 3.8 requires simpy, which is not installed.
# Successfully installed openmdao-3.23.0

# %%
# !pip install ruamel_yaml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ruamel_yaml
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 KB 4.0 MB/s eta 0:00:00
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (555 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.3/555.3 KB 14.8 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, ruamel_yaml
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wisdem 3.8 requires dearpygui, which is not installed.
# wisdem 3.8 requires marmot-agents>=0.2.5, which is not installed.
# wisdem 3.8 requires nlopt, which is not installed.
# wisdem 3.8 requires pydoe2, which is not installed.
# wisdem 3.8 requires python-benedict, which is not installed.
# wisdem 3.8 requires simpy, which is not installed.
# Successfully installed ruamel.yaml.clib-0.2.7 ruamel_yaml-0.17.21

# %%
from wisdem.nrelcsm.nrel_csm_mass_2015 import nrel_csm_2015
# 0 ---------- (marker for docs)

# 1 ---------- (marker for docs)
# OpenMDAO Problem instance
prob = om.Problem(reports=False)
prob.model = nrel_csm_2015()
prob.setup()
# 1 ---------- (marker for docs)

# 2 ---------- (marker for docs)
# Initialize variables for NREL CSM
prob["machine_rating"] = 5000.0
prob["rotor_diameter"] = 126.0
prob["turbine_class"] = 2
prob["hub_height"] = 90.0
prob["blade_number"] = 3
prob["blade_has_carbon"] = False
prob["max_tip_speed"] = 80.0
prob["max_efficiency"] = 0.90
prob["main_bearing_number"] = 2
prob["crane"] = True
# 2 ---------- (marker for docs)

# 3 ---------- (marker for docs)
# Evaluate the model
prob.run_model()
# 3 ---------- (marker for docs)

# 4 ---------- (marker for docs)
# Print all intermediate inputs and outputs to the screen
prob.model.list_inputs(units=True)
prob.model.list_outputs(units=True)
# 4 ---------- (marker for docs)
# Out:
# 231 Input(s) in 'model'
#
# varname                                    val                 units
# -----------------------------------------  ------------------  -----------
# nrel_csm_mass
#   blade
#     rotor_diameter                         [126.]              m
#     blade_mass_coeff                       [0.5]               None
#     blade_user_exp                         [2.5]               None
#   hub
#     blade_mass                             [15751.48043042]    kg
#     hub_mass_coeff                         [2.3]               None
#     hub_mass_intercept                     [1320.]             None
#   pitch
#     blade_mass                             [15751.48043042]    kg
#     pitch_bearing_mass_coeff               [0.1295]            None
#     pitch_bearing_mass_intercept           [491.31]            None
#     bearing_housing_fraction               [0.328]             None
#     mass_sys_offset                        [555.]              None
#   spinner
#     rotor_diameter                         [126.]              m
#     spinner_mass_coeff                     [15.5]              None
#     spinner_mass_intercept                 [-980.]             None
#   lss
#     blade_mass                             [15751.48043042]    kg
#     machine_rating                         [5000.]             kW
#     lss_mass_coeff                         [13.]               None
#     lss_mass_exp                           [0.65]              None
#     lss_mass_intercept                     [775.]              None
#   bearing
#     rotor_diameter                         [126.]              m
#     bearing_mass_coeff                     [0.0001]            None
#     bearing_mass_exp                       [3.5]               None
#   torque
#     rotor_diameter                         [126.]              m
#     machine_rating                         [5000.]             kW
#     max_tip_speed                          [80.]               m/s
#     max_efficiency                         [0.9]               None
#   gearbox
#     rotor_torque                           [4375000.]          N*m
#     gearbox_mass_coeff                     [113.]              None
#     gearbox_mass_exp                       [0.71]              None
#   hss
#     machine_rating                         [5000.]             kW
#     hss_mass_coeff                         [0.19894]           None
#   brake
#     rotor_torque                           [4375000.]          N*m
#     brake_mass_coeff                       [0.00122]           None
#   generator
#     machine_rating                         [5000.]             kW
#     generator_mass_coeff                   [2300.]             None
#     generator_mass_intercept               [3400.]             None
#   bedplate
#     rotor_diameter                         [126.]              m
#     bedplate_mass_exp                      [2.2]               None
#   yaw
#     rotor_diameter                         [126.]              m
#     yaw_mass_coeff                         [0.0009]            None
#     yaw_mass_exp                           [3.314]             None
#   hvac
#     machine_rating                         [5000.]             kW
#     hvac_mass_coeff                        [0.08]              None
#   cover
#     machine_rating                         [5000.]             kW
#     cover_mass_coeff                       [1.2817]            None
#     cover_mass_intercept                   [428.19]            None
#   platforms
#     bedplate_mass                          [41765.26095285]    kg
#     platforms_mass_coeff                   [0.125]             None
#     crane_weight                           [3000.]             kg
#   transformer
#     machine_rating                         [5000.]             kW
#     transformer_mass_coeff                 [1915.]             None
#     transformer_mass_intercept             [1910.]             None
#   tower
#     hub_height                             [90.]               m
#     tower_mass_coeff                       [19.828]            None
#     tower_mass_exp                         [2.0282]            None
#   turbine
#     blade_mass                             [15751.48043042]    kg
#     hub_mass                               [37548.40498997]    kg
#     pitch_system_mass                      [9334.08947551]     kg
#     spinner_mass                           [973.]              kg
#     lss_mass                               [20568.96284886]    kg
#     main_bearing_mass                      [2245.41649102]     kg
#     gearbox_mass                           [43468.32086769]    kg
#     hss_mass                               [994.7]             kg
#     brake_mass                             [5337.5]            kg
#     generator_mass                         [14900.]            kg
#     bedplate_mass                          [41765.26095285]    kg
#     yaw_mass                               [12329.96247921]    kg
#     hvac_mass                              [400.]              kg
#     cover_mass                             [6836.69]           kg
#     platforms_mass                         [8220.65761911]     kg
#     transformer_mass                       [11485.]            kg
#     tower_mass                             [182336.48057717]   kg
#   blade
#     turbine_class                          2                   Unavailable
#     blade_has_carbon                       False               Unavailable
#   pitch
#     blade_number                           3                   Unavailable
#   platforms
#     crane                                  True                Unavailable
#   turbine
#     blade_number                           3                   Unavailable
#     main_bearing_number                    2                   Unavailable
# turbine_costs
#   blade_c
#     blade_mass                             [15751.48043042]    kg
#     blade_mass_cost_coeff                  [14.6]              USD/kg
#     blade_cost_external                    [0.]                USD
#   hub_c
#     hub_mass                               [37548.40498997]    kg
#     hub_mass_cost_coeff                    [3.9]               USD/kg
#   pitch_c
#     pitch_system_mass                      [9334.08947551]     kg
#     pitch_system_mass_cost_coeff           [22.1]              USD/kg
#   spinner_c
#     spinner_mass                           [973.]              kg
#     spinner_mass_cost_coeff                [11.1]              USD/kg
#   hub_adder
#     hub_cost                               [146438.77946089]   USD
#     hub_mass                               [37548.40498997]    kg
#     pitch_system_cost                      [206283.37740871]   USD
#     pitch_system_mass                      [9334.08947551]     kg
#     spinner_cost                           [10800.3]           USD
#     spinner_mass                           [973.]              kg
#     hub_assemblyCostMultiplier             [0.]                None
#     hub_overheadCostMultiplier             [0.]                None
#     hub_profitMultiplier                   [0.]                None
#     hub_transportMultiplier                [0.]                None
#   rotor_adder
#     blade_cost                             [229971.61428418]   USD
#     blade_mass                             [15751.48043042]    kg
#     hub_system_cost                        [363522.45686961]   USD
#     hub_system_mass_tcc                    [47855.49446548]    kg
#   lss_c
#     lss_mass                               [20568.96284886]    kg
#     lss_mass_cost_coeff                    [11.9]              USD/kg
#   bearing_c
#     main_bearing_mass                      [2245.41649102]     kg
#     bearing_mass_cost_coeff                [4.5]               USD/kg
#   gearbox_c
#     gearbox_mass                           [43468.32086769]    kg
#     gearbox_mass_cost_coeff                [12.9]              USD/kg
#   hss_c
#     hss_mass                               [994.7]             kg
#     hss_mass_cost_coeff                    [6.8]               USD/kg
#   brake_c
#     brake_mass                             [5337.5]            kg
#     brake_mass_cost_coeff                  [3.6254]            USD/kg
#   generator_c
#     generator_mass                         [14900.]            kg
#     generator_mass_cost_coeff              [12.4]              USD/kg
#     generator_cost_external                [0.]                USD
#   bedplate_c
#     bedplate_mass                          [41765.26095285]    kg
#     bedplate_mass_cost_coeff               [2.9]               USD/kg
#   yaw_c
#     yaw_mass                               [12329.96247921]    kg
#     yaw_mass_cost_coeff                    [8.3]               USD/kg
#   hvac_c
#     hvac_mass                              [400.]              kg
#     hvac_mass_cost_coeff                   [124.]              USD/kg
#   controls_c
#     machine_rating                         [5000.]             kW
#     controls_machine_rating_cost_coeff     [21.15]             USD/kW
#   converter_c
#     converter_mass                         [0.]                kg
#     converter_mass_cost_coeff              [18.8]              USD/kg
#   elec_c
#     machine_rating                         [5000.]             kW
#     elec_connec_machine_rating_cost_coeff  [41.85]             USD/kW
#   cover_c
#     cover_mass                             [6836.69]           kg
#     cover_mass_cost_coeff                  [5.7]               USD/kg
#   platforms_c
#     platforms_mass                         [8220.65761911]     kg
#     platforms_mass_cost_coeff              [17.1]              USD/kg
#     crane_cost                             [12000.]            USD
#   transformer_c
#     transformer_mass                       [11485.]            kg
#     transformer_mass_cost_coeff            [18.8]              USD/kg
#   nacelle_adder
#     lss_cost                               [244770.65790145]   USD
#     lss_mass                               [20568.96284886]    kg
#     main_bearing_cost                      [10104.37420958]    USD
#     main_bearing_mass                      [2245.41649102]     kg
#     gearbox_cost                           [560741.33919321]   USD
#     gearbox_mass                           [43468.32086769]    kg
#     hss_cost                               [6763.96]           USD
#     hss_mass                               [994.7]             kg
#     brake_cost                             [19350.5725]        USD
#     brake_mass                             [5337.5]            kg
#     generator_cost                         [184760.]           USD
#     generator_mass                         [14900.]            kg
#     bedplate_cost                          [121119.25676326]   USD
#     bedplate_mass                          [41765.26095285]    kg
#     yaw_system_cost                        [102338.68857747]   USD
#     yaw_mass                               [12329.96247921]    kg
#     converter_cost                         [0.]                USD
#     converter_mass                         [0.]                kg
#     hvac_cost                              [49600.]            USD
#     hvac_mass                              [400.]              kg
#     cover_cost                             [38969.133]         USD
#     cover_mass                             [6836.69]           kg
#     elec_cost                              [209250.]           USD
#     controls_cost                          [105750.]           USD
#     platforms_mass                         [8220.65761911]     kg
#     platforms_cost                         [101273.24528671]   USD
#     transformer_cost                       [215918.]           USD
#     transformer_mass                       [11485.]            kg
#     nacelle_assemblyCostMultiplier         [0.]                None
#     nacelle_overheadCostMultiplier         [0.]                None
#     nacelle_profitMultiplier               [0.]                None
#     nacelle_transportMultiplier            [0.]                None
#   tower_c
#     tower_mass                             [182336.48057717]   kg
#     tower_mass_cost_coeff                  [2.9]               USD/kg
#     tower_cost_external                    [0.]                USD
#   tower_adder
#     tower_parts_cost                       [528775.7936738]    USD
#     tower_assemblyCostMultiplier           [0.]                None
#     tower_overheadCostMultiplier           [0.]                None
#     tower_profitMultiplier                 [0.]                None
#     tower_transportMultiplier              [0.]                None
#   turbine_c
#     rotor_cost                             [1053437.29972214]  USD
#     rotor_mass_tcc                         [95109.93575675]    kg
#     nacelle_cost                           [1980813.60164125]  USD
#     nacelle_mass_tcc                       [170797.88774975]   kg
#     tower_cost                             [528775.7936738]    USD
#     tower_mass                             [182336.48057717]   kg
#     machine_rating                         [5000.]             kW
#     turbine_assemblyCostMultiplier         [0.]                None
#     turbine_overheadCostMultiplier         [0.]                None
#     turbine_profitMultiplier               [0.]                None
#     turbine_transportMultiplier            [0.]                None
#   outputs
#     blade_cost                             [229971.61428418]   USD
#     blade_mass                             [15751.48043042]    kg
#     hub_cost                               [146438.77946089]   USD
#     hub_mass                               [37548.40498997]    kg
#     pitch_system_cost                      [206283.37740871]   USD
#     pitch_system_mass                      [9334.08947551]     kg
#     spinner_cost                           [10800.3]           USD
#     spinner_mass                           [973.]              kg
#     lss_cost                               [244770.65790145]   USD
#     lss_mass                               [20568.96284886]    kg
#     main_bearing_cost                      [10104.37420958]    USD
#     main_bearing_mass                      [2245.41649102]     kg
#     gearbox_cost                           [560741.33919321]   USD
#     gearbox_mass                           [43468.32086769]    kg
#     hss_cost                               [6763.96]           USD
#     hss_mass                               [994.7]             kg
#     brake_cost                             [19350.5725]        USD
#     brake_mass                             [5337.5]            kg
#     generator_cost                         [184760.]           USD
#     generator_mass                         [14900.]            kg
#     bedplate_cost                          [121119.25676326]   USD
#     bedplate_mass                          [41765.26095285]    kg
#     yaw_system_cost                        [102338.68857747]   USD
#     yaw_mass                               [12329.96247921]    kg
#     hvac_cost                              [49600.]            USD
#     hvac_mass                              [400.]              kg
#     cover_cost                             [38969.133]         USD
#     cover_mass                             [6836.69]           kg
#     elec_cost                              [209250.]           USD
#     controls_cost                          [105750.]           USD
#     platforms_cost                         [101273.24528671]   USD
#     transformer_cost                       [215918.]           USD
#     transformer_mass                       [11485.]            kg
#     converter_cost                         [0.]                USD
#     converter_mass                         [0.]                kg
#     rotor_cost                             [1053437.29972214]  USD
#     rotor_mass_tcc                         [95109.93575675]    kg
#     nacelle_cost                           [1980813.60164125]  USD
#     nacelle_mass_tcc                       [170797.88774975]   kg
#     tower_cost                             [528775.7936738]    USD
#     tower_mass                             [182336.48057717]   kg
#     turbine_cost                           [3563026.69503719]  USD
#     turbine_cost_kW                        [712.60533901]      USD/kW
#     turbine_mass_tcc                       [448244.30408368]   kg
#   rotor_adder
#     blade_number                           3                   Unavailable
#   platforms_c
#     crane                                  True                Unavailable
#   nacelle_adder
#     main_bearing_number                    2                   Unavailable
#
#
# 53 Explicit Output(s) in 'model'
#
# varname                  val                 units
# -----------------------  ------------------  ------
# nrel_csm_mass
#   blade
#     blade_mass           [15751.48043042]    kg
#   hub
#     hub_mass             [37548.40498997]    kg
#   pitch
#     pitch_system_mass    [9334.08947551]     kg
#   spinner
#     spinner_mass         [973.]              kg
#   lss
#     lss_mass             [20568.96284886]    kg
#   bearing
#     main_bearing_mass    [2245.41649102]     kg
#   torque
#     rated_rpm            [12.1260909]        rpm
#     rotor_torque         [4375000.]          N*m
#   gearbox
#     gearbox_mass         [43468.32086769]    kg
#   hss
#     hss_mass             [994.7]             kg
#   brake
#     brake_mass           [5337.5]            kg
#   generator
#     generator_mass       [14900.]            kg
#   bedplate
#     bedplate_mass        [41765.26095285]    kg
#   yaw
#     yaw_mass             [12329.96247921]    kg
#   hvac
#     hvac_mass            [400.]              kg
#   cover
#     cover_mass           [6836.69]           kg
#   platforms
#     platforms_mass       [8220.65761911]     kg
#   transformer
#     transformer_mass     [11485.]            kg
#   tower
#     tower_mass           [182336.48057717]   kg
#   turbine
#     hub_system_mass      [47855.49446548]    kg
#     rotor_mass           [95109.93575675]    kg
#     nacelle_mass         [170797.88774975]   kg
#     turbine_mass         [448244.30408368]   kg
# turbine_costs
#   blade_c
#     blade_cost           [229971.61428418]   USD
#   hub_c
#     hub_cost             [146438.77946089]   USD
#   pitch_c
#     pitch_system_cost    [206283.37740871]   USD
#   spinner_c
#     spinner_cost         [10800.3]           USD
#   hub_adder
#     hub_system_mass_tcc  [47855.49446548]    kg
#     hub_system_cost      [363522.45686961]   USD
#   rotor_adder
#     rotor_cost           [1053437.29972214]  USD
#     rotor_mass_tcc       [95109.93575675]    kg
#   lss_c
#     lss_cost             [244770.65790145]   USD
#   bearing_c
#     main_bearing_cost    [10104.37420958]    USD
#   gearbox_c
#     gearbox_cost         [560741.33919321]   USD
#   hss_c
#     hss_cost             [6763.96]           USD
#   brake_c
#     brake_cost           [19350.5725]        USD
#   generator_c
#     generator_cost       [184760.]           USD
#   bedplate_c
#     bedplate_cost        [121119.25676326]   USD
#   yaw_c
#     yaw_system_cost      [102338.68857747]   USD
#   hvac_c
#     hvac_cost            [49600.]            USD
#   controls_c
#     controls_cost        [105750.]           USD
#   converter_c
#     converter_cost       [0.]                USD
#   elec_c
#     elec_cost            [209250.]           USD
#   cover_c
#     cover_cost           [38969.133]         USD
#   platforms_c
#     platforms_cost       [101273.24528671]   USD
#   transformer_c
#     transformer_cost     [215918.]           USD
#   nacelle_adder
#     nacelle_cost         [1980813.60164125]  USD
#     nacelle_mass_tcc     [170797.88774975]   kg
#   tower_c
#     tower_parts_cost     [528775.7936738]    USD
#   tower_adder
#     tower_cost           [528775.7936738]    USD
#   turbine_c
#     turbine_mass_tcc     [448244.30408368]   kg
#     turbine_cost         [3563026.69503719]  USD
#     turbine_cost_kW      [712.60533901]      USD/kW
#
#
# 0 Implicit Output(s) in 'model'
# [('nrel_csm_mass.blade.blade_mass',
#   {'val': array([15751.48043042]), 'units': 'kg'}),
#  ('nrel_csm_mass.hub.hub_mass',
#   {'val': array([37548.40498997]), 'units': 'kg'}),
#  ('nrel_csm_mass.pitch.pitch_system_mass',
#   {'val': array([9334.08947551]), 'units': 'kg'}),
#  ('nrel_csm_mass.spinner.spinner_mass', {'val': array([973.]), 'units': 'kg'}),
#  ('nrel_csm_mass.lss.lss_mass',
#   {'val': array([20568.96284886]), 'units': 'kg'}),
#  ('nrel_csm_mass.bearing.main_bearing_mass',
#   {'val': array([2245.41649102]), 'units': 'kg'}),
#  ('nrel_csm_mass.torque.rated_rpm',
#   {'val': array([12.1260909]), 'units': 'rpm'}),
#  ('nrel_csm_mass.torque.rotor_torque',
#   {'val': array([4375000.]), 'units': 'N*m'}),
#  ('nrel_csm_mass.gearbox.gearbox_mass',
#   {'val': array([43468.32086769]), 'units': 'kg'}),
#  ('nrel_csm_mass.hss.hss_mass', {'val': array([994.7]), 'units': 'kg'}),
#  ('nrel_csm_mass.brake.brake_mass', {'val': array([5337.5]), 'units': 'kg'}),
#  ('nrel_csm_mass.generator.generator_mass',
#   {'val': array([14900.]), 'units': 'kg'}),
#  ('nrel_csm_mass.bedplate.bedplate_mass',
#   {'val': array([41765.26095285]), 'units': 'kg'}),
#  ('nrel_csm_mass.yaw.yaw_mass',
#   {'val': array([12329.96247921]), 'units': 'kg'}),
#  ('nrel_csm_mass.hvac.hvac_mass', {'val': array([400.]), 'units': 'kg'}),
#  ('nrel_csm_mass.cover.cover_mass', {'val': array([6836.69]), 'units': 'kg'}),
#  ('nrel_csm_mass.platforms.platforms_mass',
#   {'val': array([8220.65761911]), 'units': 'kg'}),
#  ('nrel_csm_mass.transformer.transformer_mass',
#   {'val': array([11485.]), 'units': 'kg'}),
#  ('nrel_csm_mass.tower.tower_mass',
#   {'val': array([182336.48057717]), 'units': 'kg'}),
#  ('nrel_csm_mass.turbine.hub_system_mass',
#   {'val': array([47855.49446548]), 'units': 'kg'}),
#  ('nrel_csm_mass.turbine.rotor_mass',
#   {'val': array([95109.93575675]), 'units': 'kg'}),
#  ('nrel_csm_mass.turbine.nacelle_mass',
#   {'val': array([170797.88774975]), 'units': 'kg'}),
#  ('nrel_csm_mass.turbine.turbine_mass',
#   {'val': array([448244.30408368]), 'units': 'kg'}),
#  ('turbine_costs.blade_c.blade_cost',
#   {'val': array([229971.61428418]), 'units': 'USD'}),
#  ('turbine_costs.hub_c.hub_cost',
#   {'val': array([146438.77946089]), 'units': 'USD'}),
#  ('turbine_costs.pitch_c.pitch_system_cost',
#   {'val': array([206283.37740871]), 'units': 'USD'}),
#  ('turbine_costs.spinner_c.spinner_cost',
#   {'val': array([10800.3]), 'units': 'USD'}),
#  ('turbine_costs.hub_adder.hub_system_mass_tcc',
#   {'val': array([47855.49446548]), 'units': 'kg'}),
#  ('turbine_costs.hub_adder.hub_system_cost',
#   {'val': array([363522.45686961]), 'units': 'USD'}),
#  ('turbine_costs.rotor_adder.rotor_cost',
#   {'val': array([1053437.29972214]), 'units': 'USD'}),
#  ('turbine_costs.rotor_adder.rotor_mass_tcc',
#   {'val': array([95109.93575675]), 'units': 'kg'}),
#  ('turbine_costs.lss_c.lss_cost',
#   {'val': array([244770.65790145]), 'units': 'USD'}),
#  ('turbine_costs.bearing_c.main_bearing_cost',
#   {'val': array([10104.37420958]), 'units': 'USD'}),
#  ('turbine_costs.gearbox_c.gearbox_cost',
#   {'val': array([560741.33919321]), 'units': 'USD'}),
#  ('turbine_costs.hss_c.hss_cost', {'val': array([6763.96]), 'units': 'USD'}),
#  ('turbine_costs.brake_c.brake_cost',
#   {'val': array([19350.5725]), 'units': 'USD'}),
#  ('turbine_costs.generator_c.generator_cost',
#   {'val': array([184760.]), 'units': 'USD'}),
#  ('turbine_costs.bedplate_c.bedplate_cost',
#   {'val': array([121119.25676326]), 'units': 'USD'}),
#  ('turbine_costs.yaw_c.yaw_system_cost',
#   {'val': array([102338.68857747]), 'units': 'USD'}),
#  ('turbine_costs.hvac_c.hvac_cost', {'val': array([49600.]), 'units': 'USD'}),
#  ('turbine_costs.controls_c.controls_cost',
#   {'val': array([105750.]), 'units': 'USD'}),
#  ('turbine_costs.converter_c.converter_cost',
#   {'val': array([0.]), 'units': 'USD'}),
#  ('turbine_costs.elec_c.elec_cost', {'val': array([209250.]), 'units': 'USD'}),
#  ('turbine_costs.cover_c.cover_cost',
#   {'val': array([38969.133]), 'units': 'USD'}),
#  ('turbine_costs.platforms_c.platforms_cost',
#   {'val': array([101273.24528671]), 'units': 'USD'}),
#  ('turbine_costs.transformer_c.transformer_cost',
#   {'val': array([215918.]), 'units': 'USD'}),
#  ('turbine_costs.nacelle_adder.nacelle_cost',
#   {'val': array([1980813.60164125]), 'units': 'USD'}),
#  ('turbine_costs.nacelle_adder.nacelle_mass_tcc',
#   {'val': array([170797.88774975]), 'units': 'kg'}),
#  ('turbine_costs.tower_c.tower_parts_cost',
#   {'val': array([528775.7936738]), 'units': 'USD'}),
#  ('turbine_costs.tower_adder.tower_cost',
#   {'val': array([528775.7936738]), 'units': 'USD'}),
#  ('turbine_costs.turbine_c.turbine_mass_tcc',
#   {'val': array([448244.30408368]), 'units': 'kg'}),
#  ('turbine_costs.turbine_c.turbine_cost',
#   {'val': array([3563026.69503719]), 'units': 'USD'}),
#  ('turbine_costs.turbine_c.turbine_cost_kW',
#   {'val': array([712.60533901]), 'units': 'USD/kW'})]

# %%
prob['turbine_costs.turbine_c.turbine_cost']
# Out:
# array([3563026.69503719])

# %%
from wisdem.nrelcsm.nrel_csm_mass_2015 import nrel_csm_2015
def nrelcsm_wrapper(rated_power=5000, rotor_diameter=126):
  
  # 0 ---------- (marker for docs)

  # 1 ---------- (marker for docs)
  # OpenMDAO Problem instance
  prob = om.Problem(reports=False)
  prob.model = nrel_csm_2015()
  prob.setup()
  # 1 ---------- (marker for docs)

  # 2 ---------- (marker for docs)
  # Initialize variables for NREL CSM
  prob["machine_rating"] = rated_power
  prob["rotor_diameter"] = rotor_diameter
  prob["turbine_class"] = 2
  prob["hub_height"] = 90.0
  prob["blade_number"] = 3
  prob["blade_has_carbon"] = False
  prob["max_tip_speed"] = 80.0
  prob["max_efficiency"] = 0.90
  prob["main_bearing_number"] = 2
  prob["crane"] = True
  # 2 ---------- (marker for docs)

  # 3 ---------- (marker for docs)
  # Evaluate the model
  prob.run_model()
  # 3 ---------- (marker for docs)

  # 4 ---------- (marker for docs)
  # Print all intermediate inputs and outputs to the screen
   # 4 ---------- (marker for docs)
  return prob['turbine_costs.turbine_c.turbine_cost']

# %%
nrelcsm_wrapper(rated_power=5000, rotor_diameter=126)
# Out:
# array([3563026.69503719])
