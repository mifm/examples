# %% [markdown]
# <a href="https://colab.research.google.com/github/mifm/examples/blob/master/wd0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install py_wake
# !pip install topfarm

# %%
# %%capture
from py_wake.examples.data.hornsrev1 import Hornsrev1Site, V80
from py_wake.turbulence_models.stf import STF2017TurbulenceModel
from py_wake import NOJ
from py_wake.deflection_models import JimenezWakeDeflection
from topfarm.utils import regular_generic_layout

n_wt = 40
wt = V80()
d = wt.diameter()
site = Hornsrev1Site()
sx = 4 * d
sy = 5 * d
x, y = regular_generic_layout(n_wt, sx, sy, stagger=0, rotation=0)
farm = NOJ(site, wt, turbulenceModel=STF2017TurbulenceModel(), deflectionModel=JimenezWakeDeflection(),)

# %%
sim_res = farm(x, y, ws=8, wd=1, tilt=0, yaw=0)

# %%
sim_res.flow_map(ws=8,wd=1).plot_wake_map()

# %%
farm(x, y, ws=8, wd=0, tilt=0, yaw=0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-0fce14fa19f3> in <cell line: 0>()
# ----> 1 farm(x, y, ws=8, wd=0, tilt=0, yaw=0)
#
# /usr/local/lib/python3.11/dist-packages/py_wake/wind_farm_models/wind_farm_model.py in __call__(self, x, y, h, type, wd, ws, time, verbose, n_cpu, wd_chunks, ws_chunks, return_simulationResult, **kwargs)
#     138             ws = np.zeros(len(time))
#     139
# --> 140         res = self._run(x, y, h=h, type=type, wd=wd, ws=ws, time=time, verbose=verbose,
#     141                         n_cpu=n_cpu, wd_chunks=wd_chunks, ws_chunks=ws_chunks, **kwargs)
#     142         if return_simulationResult:
#
# /usr/local/lib/python3.11/dist-packages/py_wake/wind_farm_models/wind_farm_model.py in _run(self, x, y, h, type, wd, ws, time, verbose, n_cpu, wd_chunks, ws_chunks, **kwargs)
# ...
